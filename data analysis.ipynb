# %%
# importing libraries
import numpy as np
import pandas as pd

# %%
# extract the file
data = pd.ExcelFile('KPMG_VI_New_raw_data_update_final.xlsx')

# %%
#read specific sheet
data1 = pd.read_excel(data, 'Transactions')

# %%
# display 1st 10 data 
data1.head(10)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
# 6               7          22         1542       2017-04-21           1.0
# 7               8          15         2459       2017-07-15           0.0
# 8               9          67         1305       2017-08-10           0.0
# 9              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# ...

# %%
# gives information  abut the data
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
data1.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19803.000000             19803.000000
# mean      556.046951             38199.776549
# std       405.955660              2875.201110
# min         7.210000             33259.000000
# ...

# %%
columns = data1.columns

# %%
for column in columns:
    if data1[column].dtype == 'object':
        print(column,"total unique values are :",data1[column].unique(),'\n')
# Out:
# order_status total unique values are : ['Approved' 'Cancelled']
#
# brand total unique values are : ['Solex' 'Trek Bicycles' 'OHM Cycles' 'Norco Bicycles' 'Giant Bicycles'
#  'WeareA2B' nan]
#
# product_line total unique values are : ['Standard' 'Road' 'Mountain' 'Touring' nan]
#
# product_class total unique values are : ['medium' 'low' 'high' nan]
#
# product_size total unique values are : ['medium' 'large' 'small' nan]

# %%
data1.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
data1.dropna()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
data1 = data1.dropna()

# %%
data1.isna().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
columns = data1.columns

# %%
for column in columns:
    if data1[column].dtype == 'object':
        print(column,'total unique values are:',data1[column].unique(),'\n')
    else:
        pass
# Out:
# order_status total unique values are: ['Approved' 'Cancelled']
#
# brand total unique values are: ['Solex' 'Trek Bicycles' 'OHM Cycles' 'Norco Bicycles' 'Giant Bicycles'
#  'WeareA2B']
#
# product_line total unique values are: ['Standard' 'Road' 'Mountain' 'Touring']
#
# product_class total unique values are: ['medium' 'low' 'high']
#
# product_size total unique values are: ['medium' 'large' 'small']

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   transaction_date         19445 non-null  datetime64[ns]
#  4   online_order             19445 non-null  float64
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
# ...

# %%
len(data1)
# Out:
# 19445

# %%
data1.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
data1.drop('product_first_sold_date',inplace=True,axis=1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    19445 non-null  int64
#  1   product_id        19445 non-null  int64
#  2   customer_id       19445 non-null  int64
#  3   transaction_date  19445 non-null  datetime64[ns]
#  4   online_order      19445 non-null  float64
#  5   order_status      19445 non-null  object
#  6   brand             19445 non-null  object
#  7   product_line      19445 non-null  object
#  8   product_class     19445 non-null  object
#  9   product_size      19445 non-null  object
#  10  list_price        19445 non-null  float64
#  11  standard_cost     19445 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 1.6+ MB

# %%
profit = data1['list_price']-data1['standard_cost']

# %%
print(profit)
# Out:
# 0          17.87
# 1        1702.55
# 2        1544.61
# 3         817.36
# 4        1055.82
#           ...
# 19995     802.26
# 19996     104.24
# 19997    1592.19
# 19998      91.15
# 19999     195.34
# Length: 19445, dtype: float64

# %%
data1 = pd.concat([data1,profit],axis = 1)

# %%
print(data1)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
data1 = data1.rename(columns = {0:'profit'})

# %%
data1
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
data2 = pd.read_excel(data,'NewCustomerList')

# %%
data2.head(10)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
# 5      Druci    Brandli  Female                                   39
# 6   Rutledge      Hallt    Male                                   23
# 7     Nancie       Vian  Female                                   74
# 8       Duff  Karlowicz    Male                                   50
# 9    Barthel     Docket    Male                                   72
#
#          DOB                     job_title job_industry_category  \
# 0 1957-07-12               General Manager         Manufacturing
# 1 1970-03-22           Structural Engineer              Property
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
data2.drop(columns = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],inplace=True)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
data2.sort_values(by = ['DOB'],inplace = True)

# %%
data2['DOB'].head(10)
# Out:
# 797   1938-06-08
# 885   1938-06-09
# 769   1938-08-05
# 585   1938-08-30
# 265   1938-08-31
# 689   1938-09-02
# 414   1938-09-10
# 191   1938-10-16
# 18    1938-11-09
# 406   1938-11-29
# Name: DOB, dtype: datetime64[ns]

# %%
data2.isna().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2.isna().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# dtype: int64

# %%
columns1 = data2.columns

# %%
for column in columns1:
    if data2[column].dtype == 'object':
        if(column=='last_name'):
            continue
        if(column=='first_name'):
            continue
            
        else:
            print(column,"total number of unique values are:",data2[column].unique(),'\n')
            print("-"*30)
    else:
            pass
# Out:
# gender total number of unique values are: ['Male' 'Female']
#
# ------------------------------
# job_title total number of unique values are: ['General Manager' 'Cost Accountant' 'Web Developer II'
#  'Clinical Specialist' 'Graphic Designer' 'Structural Analysis Engineer'
#  'Account Representative IV' 'Nuclear Power Engineer' 'Senior Editor'
#  'Human Resources Assistant III' 'Staff Scientist' 'VP Marketing'
#  'Marketing Manager' 'Editor' 'Operator' 'Legal Assistant'
#  'Computer Systems Analyst III' 'Software Engineer II' 'Developer III'
#  'Programmer III' 'Accounting Assistant II' 'Director of Sales'
#  'Librarian' 'Environmental Tech' 'Tax Accountant' 'Associate Professor'
#  'Sales Representative' 'Design Engineer' 'Data Coordiator'
#  'Senior Financial Analyst' 'Environmental Specialist'
#  'Accounting Assistant I' 'Social Worker' 'Human Resources Assistant IV'
#  'Quality Control Specialist' 'Chemical Engineer' 'Teacher'
# ...

# %%
data3 = pd.read_excel(data, 'CustomerDemographic')

# %%
data3.head(10)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
# 5            6            Curr  Duckhouse    Male
# 6            7            Fina     Merali  Female
# 7            8             Rod      Inder    Male
# 8            9            Mala       Lind  Female
# 9           10        Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   33 1961-10-03
# 4                                   56 1977-05-13
# 5                                   35 1966-09-16
# 6                                    6 1976-02-23
# ...

# %%
data3.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
data3.dropna(inplace=True)

# %%
data3.isna().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# default                                0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
data3.drop('default',inplace=True,axis = 1)

# %%
data3
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp       F
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 8                                      97 1973-03-10
# 9                                      49 1988-10-11
# ...                                   ...        ...
# ...

# %%
columns3 = data3.columns

# %%
for column in columns3:
    if data3[column].dtype == 'object':
        print(column,"total unique values are :",data3[column].unique(),'\n')
# Out:
# first_name total unique values are : ['Laraine' 'Eli' 'Arlin' ... 'Stephie' 'Rusty' 'Blanch']
#
# last_name total unique values are : ['Medendorp' 'Bockman' 'Dearle' ... 'Byars' 'Iapico' 'Halgarth']
#
# gender total unique values are : ['F' 'Male' 'Female' 'Femal']
#
# job_title total unique values are : ['Executive Secretary' 'Administrative Officer' 'Recruiting Manager'
#  'Business Systems Development Analyst' 'Senior Quality Engineer'
#  'Nuclear Power Engineer' 'Developer I' 'Account Executive'
#  'Junior Executive' 'Geological Engineer' 'Project Manager'
#  'Safety Technician I' 'Research Assistant I' 'Accounting Assistant III'
#  'Editor' 'Research Nurse' 'Safety Technician III' 'Staff Accountant III'
#  'Legal Assistant' 'Information Systems Manager' 'Social Worker'
#  'Senior Cost Accountant' 'Assistant Media Planner'
#  'Payment Adjustment Coordinator' 'Food Chemist' 'Accountant III'
#  'Director of Sales' 'Senior Financial Analyst' 'Registered Nurse'
# ...

# %%
clean_data = {'gender':{'M' : 'Male','F' : 'Female','Femal' : 'Female','U' : 'Not being shared'}}

# %%
data3.replace(clean_data,inplace = True)

# %%
data3
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 8                                      97 1973-03-10
# 9                                      49 1988-10-11
# ...                                   ...        ...
# ...

# %%
data3['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data3.sort_values(by = "DOB",inplace = True)

# %%
data3
# Out:
#       customer_id first_name    last_name  gender  \
# 719           720     Darrel        Canet    Male
# 1091         1092     Katlin      Creddon  Female
# 2412         2413      Abbey       Murrow    Male
# 657           658       Donn      Bonnell    Male
# 1242         1243    Robbert       Blakey    Male
# ...           ...        ...          ...     ...
# 1518         1519     Marwin      Jeyness    Male
# 1401         1402    Hillier      Andraud    Male
# 3948         3949      Costa  Sleightholm    Male
# 2295         2296   Nathalia       Sanger  Female
# 65             66     Anselm        Gawne    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 719                                    67 1931-10-23
# 1091                                   56 1935-08-22
# 2412                                   27 1943-08-11
# 657                                    38 1944-01-24
# 1242                                   73 1953-08-09
# ...

# %%
data3.drop(data3.index[0],inplace=True)

# %%
data3.head(10)
# Out:
#       customer_id first_name  last_name  gender  \
# 2412         2413      Abbey     Murrow    Male
# 657           658       Donn    Bonnell    Male
# 1242         1243    Robbert     Blakey    Male
# 1176         1177   Bobbette      Pozzi  Female
# 3470         3471      Brita     Afonso  Female
# 2812         2813    Lillian   Crookall  Female
# 2018         2019       Neda     Perkis  Female
# 559           560     Dorree      Sanja  Female
# 0               1    Laraine  Medendorp  Female
# 1914         1915      Dusty    Tesimon  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 2412                                   27 1943-08-11
# 657                                    38 1944-01-24
# 1242                                   73 1953-08-09
# 1176                                   47 1953-08-31
# 3470                                   95 1953-09-05
# 2812                                   51 1953-09-10
# 2018                                   48 1953-09-13
# ...

# %%
columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
data4 = pd.read_excel(data, 'CustomerAddress')

# %%
data4.head(10)
# Out:
#    customer_id                  address  postcode            state    country  \
# 0            1       060 Morning Avenue      2016  New South Wales  Australia
# 1            2      6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4       0 Holy Cross Court      4211              QLD  Australia
# 3            5      17979 Del Mar Point      2448  New South Wales  Australia
# 4            6         9 Oakridge Court      3216              VIC  Australia
# 5            7         4 Delaware Trail      2210  New South Wales  Australia
# 6            8      49 Londonderry Lane      2650  New South Wales  Australia
# 7            9          97736 7th Trail      2023  New South Wales  Australia
# 8           11     93405 Ludington Park      3044              VIC  Australia
# 9           12  44339 Golden Leaf Alley      4557              QLD  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# ...

# %%
data4['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'Victoria'], dtype=object)

# %%
clean_data1 = {'state':{'NSW' : 'New South Wales','VIC' : 'Victoria'}}

# %%
data4.replace(clean_data1,inplace = True)

# %%
data4['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'Victoria'], dtype=object)

# %%
data4.tail(35)
# Out:
#       customer_id                     address  postcode            state  \
# 3964         3969           8578 Mifflin Pass      2170  New South Wales
# 3965         3970           02 Fair Oaks Lane      3977         Victoria
# 3966         3971             910 Becker Pass      2526  New South Wales
# 3967         3972          08 Dennis Crossing      3184         Victoria
# 3968         3973             4 Express Plaza      2191  New South Wales
# 3969         3974        81609 Vernon Terrace      3934         Victoria
# 3970         3975             37 Hintze Court      2168  New South Wales
# 3971         3976            07 Morning Court      3805         Victoria
# 3972         3977         327 Loeprich Street      3187         Victoria
# 3973         3978       5106 Northridge Drive      2560  New South Wales
# 3974         3979  9754 High Crossing Terrace      2148  New South Wales
# 3975         3980         7 Meadow Vale Court      2114  New South Wales
# ...
